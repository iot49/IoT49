# %% [markdown]
# # Dev mp-server (esp32, server)

# %% [markdown]
# ## Micropython server

# %%
# %discover
# Out:
# test-samd                      serial:///dev/cu.usbmodem1413201
# test-esp32                     ws://10.39.40.135:8266
# test-esp32                     serial:///dev/cu.usbserial-0160B5B8
# test-argon                     serial:///dev/cu.usbmodem1413101

# %%
# %connect test-stm32
print(5)
# %rsync
# %softreset
# Out:
# Connected to test-stm32 @ serial:///dev/cu.usbmodem208E307542521
# 5
# DELETE  log.txt
# UPDATE  main.py
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!   softreset ...     !!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
# %cat log.txt
# Out:
# import start_urpc
# from urpc import *
# from mp import start_server
# start_server()

# %%
# %rlist
# Out:
# test-stm32: [Errno 2] could not open port /dev/cu.usbmodem208E307542521: [Errno 2] No such file or directory: '/dev/cu.usbmodem208E307542521'

# %%
# %discover
# %connect test-stm32
# %rsync
# %softreset

import start_urpc
from urpc import *

import sys
sys_ = import_('sys')

from mp import start_server
start_server()
# Out:
# test-samd                      serial:///dev/cu.usbmodem1413201
# test-stm32                     serial:///dev/cu.usbmodem208E307542521
# test-argon                     serial:///dev/cu.usbmodem1413101
# Connected to test-stm32 @ serial:///dev/cu.usbmodem208E307542521
# UPDATE  lib/mp/server.py
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!   softreset ...     !!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# mp://10.39.40.129:54321
# accept ...
# accepted connection from ('10.39.40.114', 54492)
# 5
#
# closed client connection
# accepted connection from ('10.39.40.114', 54863)
# micropythonTraceback (most recent call last):
#   File "/flash/lib/mp/server.py", line 100, in do_evex
#   File "<string>", line 1, in <module>
# NameError: name '__iot49__' isn't defined
# /flashD,0,'',946684800,8
# F,1,'boot.py',1612717824,31
# D,1,'lib',1612717742,8
# D,2,'mp',1612717768,2
# F,3,'__init__.py',1612717770,50
# F,3,'server.py',1612882952,5825
# F,2,'network.py',1612717788,757
# ...
